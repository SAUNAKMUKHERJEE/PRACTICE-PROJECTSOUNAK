# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # EDA

# %%
import seaborn as sns
sns.scatterplot(x="Sex",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Rings'>

# %%
sns.scatterplot(x="Length",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Rings'>

# %%
sns.scatterplot(x="Diameter",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Rings'>

# %%
sns.scatterplot(x="Height",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Rings'>

# %%
sns.scatterplot(x="Whole weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Shucked weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Viscera weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Rings'>

# %%
sns.scatterplot(x="Shell weight",y="Rings",data=df)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Rings'>

# %% [markdown]
# # CORRELATION

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
df.corr()['Rings'].sort_values()
# Out:
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="blue",fmt='2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Describing Dataset:

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12) 
plt.show()

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
for column in df:
    if df[column].dtypes == 'object':
        encoder = LabelEncoder()
        df[column] = encoder.fit_transform(df[column])

# %%
colist=df.columns.values
graph=1
plt.figure(figsize=(10,10))
for i in range(0, len(colist)):
    plt.subplot(4,3,graph)
    sns.boxplot(df[colist[i]],color='red',orient='v')
    graph+=1
    plt.tight_layout()

# %% [markdown]
# # skewness

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
sns.displot(df['Sex'])

# %%
sns.displot(df['Length'])

# %%
sns.displot(df['Diameter'])

# %%
sns.displot(df['Height'])

# %%
sns.displot(df['Whole weight'])

# %%
sns.displot(df['Shucked weight'])

# %%
sns.displot(df['Viscera weight'])

# %%
sns.displot(df['Shell weight'])

# %%
df.corr()["Rings"]
# Out:
# Sex              -0.034627
# Length            0.556720
# Diameter          0.574660
# Height            0.557467
# Whole weight      0.540390
# Shucked weight    0.420884
# Viscera weight    0.503819
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %%
delete=pd.DataFrame([["-0.034627","Sex",'No','Alot'],["0.420884",'Shucked weight ','No','Alot']], columns=['correlation with target',"column name",'ormalised','outlayers'])

# %%
delete
# Out:
#   correlation with target      column name ormalised outlayers
# 0               -0.034627              Sex        No      Alot
# 1                0.420884  Shucked weight         No      Alot

# %%
df=df.drop(["Sex","Shucked weight"],axis=1)
df
# Out:
#       Length  Diameter  Height  Whole weight  Viscera weight  Shell weight  \
# 0      0.455     0.365   0.095        0.5140          0.1010        0.1500
# 1      0.350     0.265   0.090        0.2255          0.0485        0.0700
# 2      0.530     0.420   0.135        0.6770          0.1415        0.2100
# 3      0.440     0.365   0.125        0.5160          0.1140        0.1550
# 4      0.330     0.255   0.080        0.2050          0.0395        0.0550
# ...      ...       ...     ...           ...             ...           ...
# 4172   0.565     0.450   0.165        0.8870          0.2390        0.2490
# 4173   0.590     0.440   0.135        0.9660          0.2145        0.2605
# 4174   0.600     0.475   0.205        1.1760          0.2875        0.3080
# 4175   0.625     0.485   0.150        1.0945          0.2610        0.2960
# 4176   0.710     0.555   0.195        1.9485          0.3765        0.4950
#
#       Rings
# 0        15
# 1         7
# 2         9
# 3        10
# ...

# %% [markdown]
# # Removing outlayers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (4177, 7)

# %%
threshold=3 #rule of thumb
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  166,  166,
#         167,  168,  170,  181,  232,  236,  236,  236,  237,  237,  238,
#         238,  239,  270,  275,  277,  278,  294,  310,  313,  314,  334,
#         351,  355,  358,  358,  362,  375,  416,  417,  428,  431,  433,
#         469,  478,  480,  501,  526,  526,  530,  572,  628,  673,  674,
#         675,  678,  694,  696,  696,  719,  719,  720,  720,  744,  754,
#         756,  811,  891,  891, 1048, 1051, 1052, 1204, 1206, 1207, 1207,
#        1207, 1209, 1257, 1417, 1422, 1427, 1427, 1428, 1429, 1429, 1757,
#        1759, 1762, 1762, 1763, 1763, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
#        2436, 2459, 2471, 2623, 2624, 2624, 2709, 2710, 2810, 2811, 2811,
#        2863, 2863, 3008, 3140, 3148, 3149, 3149, 3151, 3151, 3188, 3193,
# ...

# %%
len(np.where(z>3)[0])
# Out:
# 163

# %%
z.iloc[6]
# Out:
# Length            0.050033
# Diameter          0.071741
# Height            0.250672
# Whole weight      0.104505
# Viscera weight    0.356690
# Shell weight      0.655017
# Rings             3.122516
# Name: 6, dtype: float64

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       Length  Diameter  Height  Whole weight  Viscera weight  Shell weight  \
# 0      0.455     0.365   0.095        0.5140          0.1010        0.1500
# 1      0.350     0.265   0.090        0.2255          0.0485        0.0700
# 2      0.530     0.420   0.135        0.6770          0.1415        0.2100
# 3      0.440     0.365   0.125        0.5160          0.1140        0.1550
# 4      0.330     0.255   0.080        0.2050          0.0395        0.0550
# ...      ...       ...     ...           ...             ...           ...
# 4172   0.565     0.450   0.165        0.8870          0.2390        0.2490
# 4173   0.590     0.440   0.135        0.9660          0.2145        0.2605
# 4174   0.600     0.475   0.205        1.1760          0.2875        0.3080
# 4175   0.625     0.485   0.150        1.0945          0.2610        0.2960
# 4176   0.710     0.555   0.195        1.9485          0.3765        0.4950
#
#       Rings
# 0        15
# 1         7
# 2         9
# 3        10
# ...

# %%
print("total dropped rows",df.shape[0]-df_new_z.shape[0])
# Out:
# total dropped rows 131

# %%
print("old_DataFrame",df.shape)
# Out:
# old_DataFrame (4177, 7)

# %%
print("New_DataFrame",df_new_z.shape)
# Out:
# New_DataFrame (4046, 7)

# %%
data_loss=((4177-4068)/4177)*100
data_loss
# Out:
# 2.6095283696432845

# %%
x=df_new_z.iloc[:,:-1]
#target
y=df_new_z.iloc[:,-1]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-0.68571988, -0.54623479, -1.16089794, -0.57469298, -0.69112124,
#         -0.58975404],
#        [-1.41273564, -1.40246976, -1.28225457, -1.35634361, -1.33473977,
#         -1.33465132],
#        [-0.05191335,  0.03036892, -0.13399686, -0.18628159, -0.24556199,
#         -0.08628963],
#        ...,
#        [ 0.63710117,  0.69228963,  1.91753484,  0.83469498,  1.07150164,
#          0.65106054],
#        [ 0.90789413,  0.82247862,  0.27759374,  0.68218802,  0.86107882,
#          0.56586089],
#        [ 1.93426184,  1.82544317,  1.60361855,  2.08490732,  1.70373609,
#          1.82706012]])

# %%
x.skew()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15356/3673655344.py in <module>
# ----> 1 x.skew()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'skew'

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.68571988, -0.54623479, -1.16089794, -0.57469298, -0.69112124,
#         -0.58975404],
#        [-1.41273564, -1.40246976, -1.28225457, -1.35634361, -1.33473977,
#         -1.33465132],
#        [-0.05191335,  0.03036892, -0.13399686, -0.18628159, -0.24556199,
#         -0.08628963],
#        ...,
#        [ 0.63710117,  0.69228963,  1.91753484,  0.83469498,  1.07150164,
#          0.65106054],
#        [ 0.90789413,  0.82247862,  0.27759374,  0.68218802,  0.86107882,
#          0.56586089],
#        [ 1.93426184,  1.82544317,  1.60361855,  2.08490732,  1.70373609,
#          1.82706012]])
